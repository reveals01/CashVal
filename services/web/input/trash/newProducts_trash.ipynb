# %%
import os
import pandas as pd
import requests

# %%
os.chdir("/Users/david/EnvPy/dpartners/services/web/input")

# %%
df = pd.read_csv('./BANKVISTA_securities_20230303_20230306-080502_sample.csv',sep=';')

# %%
df.head()
# Out:
#         SECURITIES  ERROR CODE  NUM FLDS       ID_ISIN CRNCY PX_CLOSE_DT  \
# 0  !!002ZS0   Mtge           0        51  ES0338540000   EUR
# 1  !!005JLV   Mtge           0        51  ES0314019011   EUR
# 2  !!008P8F   Mtge           0        51  ES0338541016   EUR
# 3  !!0094RK   Mtge           0        51  XS0159861078   EUR
# 4  !!00A6N4   Mtge           0        51  ES0338448014   EUR
#
#   PX_LAST  AMT_OUTSTANDING SP_EFF_DT RTG_SP  ... ROBECOSAM_TOTAL_STBLY_RANK  \
# 0    N.A.              0.0      N.A.   N.A.  ...                        NaN
# 1    N.A.              0.0      N.A.   N.A.  ...                        NaN
# 2    N.A.              0.0      N.A.   N.A.  ...                        NaN
# 3    N.A.              0.0      N.A.   N.A.  ...                        NaN
# 4    N.A.              0.0      N.A.   N.A.  ...                        NaN
#
#   ENVIRONMENTAL_SCORE SOCIAL_SCORE GOVERNANCE_SCORE EARN_YLD_HIST  \
# 0                 NaN          NaN              NaN           NaN
# 1                 NaN          NaN              NaN           NaN
# 2                 NaN          NaN              NaN           NaN
# 3                 NaN          NaN              NaN           NaN
# 4                 NaN          NaN              NaN           NaN
#
#   BDVD_NEXT_EST_EX_DT BDVD_PROJ_DIV_AMT DVD_SH_LAST FUND_TOTAL_ASSETS  \
# 0                 NaN               NaN         NaN               NaN
# 1                 NaN               NaN         NaN               NaN
# 2                 NaN               NaN         NaN               NaN
# 3                 NaN               NaN         NaN               NaN
# 4                 NaN               NaN         NaN               NaN
#
#   FUND_CLASS_ASSETS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 73 columns]

# %%
isin	devise	ticker	shortName	description

# %%
df_instruments=df[['ID_ISIN','CRNCY','SECURITIES']].drop_duplicates()
df_instruments=df_instruments.rename(columns={'ID_ISIN':'isin','CRNCY':'devise','SECURITIES':'ticker'})
df_instruments['shortName']='import auto'
df_instruments['description']=''
df_instruments.head()
df_instruments['isin']=df_instruments['isin'].apply(lambda x: x.strip())
df_instruments['ticker']=df_instruments['ticker'].apply(lambda x: x.strip())

# %%
js_input=df_instruments.to_json(orient='records')
js_input
# Out:
# '[{"isin":"ES0338540000","devise":"EUR","ticker":"!!002ZS0   Mtge","shortName":"import auto","description":""},{"isin":"ES0314019011","devise":"EUR","ticker":"!!005JLV   Mtge","shortName":"import auto","description":""},{"isin":"ES0338541016","devise":"EUR","ticker":"!!008P8F   Mtge","shortName":"import auto","description":""},{"isin":"XS0159861078","devise":"EUR","ticker":"!!0094RK   Mtge","shortName":"import auto","description":""},{"isin":"ES0338448014","devise":"EUR","ticker":"!!00A6N4   Mtge","shortName":"import auto","description":""},{"isin":"ES0338222013","devise":"EUR","ticker":"!!00BDGZ   Mtge","shortName":"import auto","description":""},{"isin":"ES0312369012","devise":"EUR","ticker":"!!00BMG3   Mtge","shortName":"import auto","description":""},{"isin":"IT0003575070","devise":"EUR","ticker":"!!00DAFL   Mtge","shortName":"import auto","description":""},{"isin":"XS0182690742","devise":"EUR","ticker":"!!00DFWA   Mtge","shortName":"import auto","description":""},{"isin":"ES0347861017","devise":"EUR","ticker":"!!00FM9X   Mtge","shortName":"import auto","description":""},{"isin":"XS0197194565","devise":"EUR","ticker":"!!00FTY9   Mtge","shortName":"import auto","description":""},{"isin":"ES0310110020","devise":"EUR","ticker":"!!00HJSY   Mtge","shortName":"import auto","description":""},{"isin":"ES0347862007","devise":"EUR","ticker":"!!00K0YS   Mtge","shortName":"import auto","description":""},{"isin":"ES0312380001","devise":"EUR","ticker":"!!00KCJS   Mtge","shortName":"import auto","description":""},{"isin":"FR0010302802","devise":"EUR","ticker":"!!00P9JK   Mtge","shortName":"import auto","description":""},{"isin":"ES0333763011","devise":"EUR","ticker":"!!00PZ7C   Mtge","shortName":"import auto","description":""},{"isin":"ES0347854004","devise":"EUR","ticker":"!!00QWGX   Mtge","shortName":"import auto","description":""},{"isin":"IT0004068851","devise":"EUR","ticker":"!!00R0IE   Mtge","shortName":"import auto","description":""},{"isin":"XS0268644886","devise":"EUR","ticker":"!!00T50W Mtge","shortName":"import auto","description":""},{"isin":"ES0372260028","devise":"EUR","ticker":"!!00U5P3   Mtge","shortName":"import auto","description":""},{"isin":"XS0274874832","devise":"EUR","ticker":"!!00UBVR   Mtge","shortName":"import auto","description":""},{"isin":"ES0313956023","devise":"EUR","ticker":"!!00UEPB   Mtge","shortName":"import auto","description":""},{"isin":"ES0374352021","devise":"EUR","ticker":"!!00UES8   Mtge","shortName":"import auto","description":""},{"isin":"ES0347844070","devise":"EUR","ticker":"!!00UI55   Mtge","shortName":"import auto","description":""},{"isin":"IT0004158124","devise":"EUR","ticker":"!!00USYR   Mtge","shortName":"import auto","description":""},{"isin":"ES0338058037","devise":"EUR","ticker":"!!00UT6W   Mtge","shortName":"import auto","description":""},{"isin":"ES0338058045","devise":"EUR","ticker":"!!00UT6X   Mtge","shortName":"import auto","description":""},{"isin":"ES0338058052","devise":"EUR","ticker":"!!00UT6Y   Mtge","shortName":"import auto","description":""},{"isin":"XS0284845343","devise":"EUR","ticker":"!!00VD5V   Mtge","shortName":"import auto","description":""},{"isin":"IT0004232598","devise":"EUR","ticker":"!!00Y0N6   Mtge","shortName":"import auto","description":""},{"isin":"IT0004232614","devise":"EUR","ticker":"!!00Y0N7   Mtge","shortName":"import auto","description":""},{"isin":"IT0004232648","devise":"EUR","ticker":"!!00Y0N8   Mtge","shortName":"import auto","description":""},{"isin":"XS0305672858","devise":"EUR","ticker":"!!00YDVY   Mtge","shortName":"import auto","description":""},{"isin":"IT0004247703","devise":"EUR","ticker":"!!00Z1MJ   Mtge","shortName":"import auto","description":""},{"isin":"ES0347786040","devise":"EUR","ticker":"!!00Z2J6   Mtge","shortName":"import auto","description":""},{"isin":"DE000A1GJ196","devise":"EUR","ticker":"!!01NLP9   Mtge","shortName":"import auto","description":""},{"isin":"XS0995503090","devise":"EUR","ticker":"!!025F9V  Mtge","shortName": ...

# %%
# api-endpoint
URL = "http://127.0.0.1:5001/api/setinstruments"

# sending get request and saving the response as response object
r = requests.post(url = URL, json = js_input)
  
# extracting data in json format
print(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7j/y7l1w26d1f78xx7mzqwbyds80000gn/T/ipykernel_3339/472225128.py in <module>
#       3
#       4 # sending get request and saving the response as response object
# ----> 5 r = requests.post(url = URL, json = js_input)
#       6
#       7 # extracting data in json format
#
# NameError: name 'requests' is not defined
